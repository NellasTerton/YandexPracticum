# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Комментарий ревьюера</strong></a></span><ul class="toc-item"><li><span><a href="#Краткое-резюме-по-ревью" data-toc-modified-id="Краткое-резюме-по-ревью-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><strong>Краткое резюме по ревью</strong></a></span></li><li><span><a href="#PS:" data-toc-modified-id="PS:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><strong>PS:</strong></a></span></li><li><span><a href="#Правила-оформления:" data-toc-modified-id="Правила-оформления:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span><strong>Правила оформления:</strong></a></span><ul class="toc-item"><li><span><a href="#-❌-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-Комментарий-ревьюера-(красный)-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#-⚠️-Комментарий-ревьюера-(желтый)" data-toc-modified-id="-⚠️-Комментарий-ревьюера-(желтый)-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></a></span></li><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-1.3.3.1"><span class="toc-item-num">1.3.3.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Комментарий-ревьюера-v2" data-toc-modified-id="Комментарий-ревьюера-v2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Комментарий ревьюера v2</strong></a></span><ul class="toc-item"><li><span><a href="#Краткое-резюме-по-ревью" data-toc-modified-id="Краткое-резюме-по-ревью-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><strong>Краткое резюме по ревью</strong></a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера-v3" data-toc-modified-id="Комментарий-ревьюера-v3-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>Комментарий ревьюера v3</strong></a></span><ul class="toc-item"><li><span><a href="#Краткое-резюме-по-ревью" data-toc-modified-id="Краткое-резюме-по-ревью-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><strong>Краткое резюме по ревью</strong></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-⚠️-Комментарий-ревьюера-(желтый)" data-toc-modified-id="-⚠️-Комментарий-ревьюера-(желтый)-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v2-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v2-Комментарий-ревьюера-(зеленый)-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-4.1.0.1"><span class="toc-item-num">4.1.0.1&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v2-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v2-Комментарий-ревьюера-(зеленый)-5.0.0.2"><span class="toc-item-num">5.0.0.2&nbsp;&nbsp;</span> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-⚠️-Комментарий-ревьюера-(желтый)" data-toc-modified-id="-⚠️-Комментарий-ревьюера-(желтый)-5.0.0.3"><span class="toc-item-num">5.0.0.3&nbsp;&nbsp;</span> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-5.0.0.4"><span class="toc-item-num">5.0.0.4&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-⚠️-v2-Комментарий-ревьюера-(желтый)" data-toc-modified-id="-⚠️-v2-Комментарий-ревьюера-(желтый)-5.0.0.5"><span class="toc-item-num">5.0.0.5&nbsp;&nbsp;</span> ⚠️ <font color="DarkGoldenRod">v2 Комментарий ревьюера (желтый)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-5.0.0.6"><span class="toc-item-num">5.0.0.6&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-6.0.0.1"><span class="toc-item-num">6.0.0.1&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-7.0.0.1"><span class="toc-item-num">7.0.0.1&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-7.0.0.2"><span class="toc-item-num">7.0.0.2&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-7.0.0.3"><span class="toc-item-num">7.0.0.3&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-7.0.0.4"><span class="toc-item-num">7.0.0.4&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-❌-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-Комментарий-ревьюера-(красный)-7.0.0.5"><span class="toc-item-num">7.0.0.5&nbsp;&nbsp;</span> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-7.0.0.6"><span class="toc-item-num">7.0.0.6&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v2-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v2-Комментарий-ревьюера-(зеленый)-7.0.0.7"><span class="toc-item-num">7.0.0.7&nbsp;&nbsp;</span> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-❌-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-Комментарий-ревьюера-(красный)-7.0.0.8"><span class="toc-item-num">7.0.0.8&nbsp;&nbsp;</span> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#-❌-v2-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-v2-Комментарий-ревьюера-(красный)-7.0.0.9"><span class="toc-item-num">7.0.0.9&nbsp;&nbsp;</span> ❌ <font color="FireBrick">v2 Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-7.0.0.10"><span class="toc-item-num">7.0.0.10&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v3-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v3-Комментарий-ревьюера-(зеленый)-7.0.0.11"><span class="toc-item-num">7.0.0.11&nbsp;&nbsp;</span> ✔️ <font color="green">v3 Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-7.0.0.12"><span class="toc-item-num">7.0.0.12&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li><li><span><a href="#-❌-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-Комментарий-ревьюера-(красный)-7.0.0.13"><span class="toc-item-num">7.0.0.13&nbsp;&nbsp;</span> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-7.0.0.14"><span class="toc-item-num">7.0.0.14&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v2-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v2-Комментарий-ревьюера-(зеленый)-7.0.0.15"><span class="toc-item-num">7.0.0.15&nbsp;&nbsp;</span> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Анализ-информации" data-toc-modified-id="Анализ-информации-8.0.0.1"><span class="toc-item-num">8.0.0.1&nbsp;&nbsp;</span>Анализ информации</a></span></li><li><span><a href="#Добавление-данных" data-toc-modified-id="Добавление-данных-8.0.0.2"><span class="toc-item-num">8.0.0.2&nbsp;&nbsp;</span>Добавление данных</a></span></li><li><span><a href="#Изучение-параметров" data-toc-modified-id="Изучение-параметров-8.0.0.3"><span class="toc-item-num">8.0.0.3&nbsp;&nbsp;</span>Изучение параметров</a></span></li><li><span><a href="#Удаление-выбросов" data-toc-modified-id="Удаление-выбросов-8.0.0.4"><span class="toc-item-num">8.0.0.4&nbsp;&nbsp;</span>Удаление выбросов</a></span></li><li><span><a href="#Оценка-общих-данных" data-toc-modified-id="Оценка-общих-данных-8.0.0.5"><span class="toc-item-num">8.0.0.5&nbsp;&nbsp;</span>Оценка общих данных</a></span></li><li><span><a href="#ТОП-10-населенных-пунктов" data-toc-modified-id="ТОП-10-населенных-пунктов-8.0.0.6"><span class="toc-item-num">8.0.0.6&nbsp;&nbsp;</span>ТОП-10 населенных пунктов</a></span></li><li><span><a href="#Оценка-данных-центра-СПБ-и-сравнение-с-общими-данными" data-toc-modified-id="Оценка-данных-центра-СПБ-и-сравнение-с-общими-данными-8.0.0.7"><span class="toc-item-num">8.0.0.7&nbsp;&nbsp;</span>Оценка данных центра СПБ и сравнение с общими данными</a></span></li><li><span><a href="#-❌-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-Комментарий-ревьюера-(красный)-8.0.0.8"><span class="toc-item-num">8.0.0.8&nbsp;&nbsp;</span> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#-❌-v2-Комментарий-ревьюера-(красный)" data-toc-modified-id="-❌-v2-Комментарий-ревьюера-(красный)-8.0.0.9"><span class="toc-item-num">8.0.0.9&nbsp;&nbsp;</span> ❌ <font color="FireBrick">v2 Комментарий ревьюера (красный)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-8.0.0.10"><span class="toc-item-num">8.0.0.10&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#-✔️-v3-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-v3-Комментарий-ревьюера-(зеленый)-8.0.0.11"><span class="toc-item-num">8.0.0.11&nbsp;&nbsp;</span> ✔️ <font color="green">v3 Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-✔️-Комментарий-ревьюера-(зеленый)" data-toc-modified-id="-✔️-Комментарий-ревьюера-(зеленый)-9.0.0.1"><span class="toc-item-num">9.0.0.1&nbsp;&nbsp;</span> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Кузьмич Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - небольшое исправление графиков
# - подсчет коэффициента корреляции
# - пересмотр выводов
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - [Шкала Чеддока…](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - небольшое исправление графиков
# - подсчет коэффициента корреляции
#
# Твоего внимания требует:
# - небольшое исправление графиков
# - пересмотр выводов
#
# Буду ждать твою работу на повторное ревью 😉
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v3**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - небольшое исправление графиков
# - пересмотр выводов
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# <b>Описание данных:</b>
# <br>airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# <br>balcony — число балконов
# <br>ceiling_height — высота потолков (м)
# <br>cityCenters_nearest — расстояние до центра города (м)
# <br>days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# <br>first_day_exposition — дата публикации
# <br>floor — этаж
# <br>floors_total — всего этажей в доме
# <br>is_apartment — апартаменты (булев тип)
# <br>kitchen_area — площадь кухни в квадратных метрах (м²)
# <br>last_price — цена на момент снятия с публикации
# <br>living_area — жилая площадь в квадратных метрах (м²)
# <br>locality_name — название населённого пункта
# <br>open_plan — свободная планировка (булев тип)
# <br>parks_around3000 — число парков в радиусе 3 км
# <br>parks_nearest — расстояние до ближайшего парка (м)
# <br>ponds_around3000 — число водоёмов в радиусе 3 км
# <br>ponds_nearest — расстояние до ближайшего водоёма (м)
# <br>rooms — число комнат
# <br>studio — квартира-студия (булев тип)
# <br>total_area — площадь квартиры в квадратных метрах (м²)
# <br>total_images — число фотографий квартиры в объявлении
# <br>Пояснение: апартаменты — это нежилые помещения, которые не относятся к жилому фонду, но имеют необходимые условия для проживания.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - описание данных,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - план работы
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Исправил.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Подключим необходимые для анализа библиотеки. Изначально данные показывались одной строкой, используем разделитель '\t', чтобы отобразить их корректно. В таблице 22 столбца и 23699 строк. Некоторые данные пропущены, их необходимо обработать.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Пройдемся по пропускам и типам данных
# <br>first_day_exposition - возможно, вместо object должен быть datetime;
# <br>ceiling_height - есть пропущенные значения;
# <br>floors_total - есть пропущенные значения, к тому же количество этажей - целое значение, предпочтительно сменить float64 на int64;
# <br>living_area - есть пропущенные значения;
# <br>is_apartment - есть пропущенные значения, к тому же предпочтительно сменить object на bool;
# <br>kitchen_area - есть пропущенные значения;
# <br>balcony - есть пропущенные значения, к тому же количество балконов - целое значение, предпочтительно сменить float64 на int64;
# <br>locality_name - есть пропущенные значения;
# <br>airports_nearest - есть пропущенные значения, влияние на исследование сомнительное;
# <br>cityCenters_nearest - есть пропущенные значения, влияние на исследование сильное;
# <br>parks_around3000 - есть пропущенные значения (к тому же количество парков предпочтительно перевести в int64);
# <br>parks_nearest - есть пропущенные значения, влияние на исследование сомнительное;
# <br>ponds_around3000 - есть пропущенные значения (к тому же количество парков предпочтительно перевести в int64);
# <br>ponds_nearest - есть пропущенные значения, влияние на исследование сомнительное;
# <br>days_exposition - есть пропущенные значения (к тому же количество дней предпочтительно перевести в int64).
#
# Начнем обработку со столбца last_price. Изменим данные на целочисленные и разделим на 1 млн., теперь данные будут отображаться в миллионах рублей (на гистограмме выглядит значительно лучше):

# %%
data['last_price'] = data['last_price'].astype(int)
data['last_price'] = data['last_price'] / 1000000
print(data['last_price'])
# Out:
# 0        13.000
# 1         3.350
# 2         5.196
# 3        64.900
# 4        10.000
#           ...
# 23694     9.700
# 23695     3.100
# 23696     2.500
# 23697    11.475
# 23698     1.350
# Name: last_price, Length: 23699, dtype: float64

# %% [markdown]
# Продолжим обработку, столбец first_day_exposition:

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],format = '%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Обработаем столбец ceiling_height:

# %%
print(data['ceiling_height'].describe())
print ()
print('Количество квартир с потолком выше 10 метров:', data['ceiling_height'][data['ceiling_height'] > 10].count())
print('Количество квартир с потолком ниже 2.1 метра:', data['ceiling_height'][data['ceiling_height'] < 2.1].count())
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64
#
# Количество квартир с потолком выше 10 метров: 25
# Количество квартир с потолком ниже 2.1 метра: 14

# %% [markdown]
# Видим, что заполнение пропусков средними значениями при максимальной высоте 100 метров, указанной некорректно, будет неверным. Применим медианные значения, заменим значения меньше 2,1 м. (минимальная высота потолка по закону) и выше 5 метров (если и есть потолки выше, их процент крайне мал). Данные также можно удалить, их общее количество для интереса подсчитал (всего 14 + 25 = 39 строк). Интересно было поработать с функцией where:

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
data['ceiling_height'] = data['ceiling_height'].where(~(data['ceiling_height'] < 2.1), 2.1)
data['ceiling_height'] = data['ceiling_height'].where(~(data['ceiling_height'] > 5), 5)

# %% [markdown]
# Обработаем столбец floors_total. Узнаем количество пустых строк:

# %%
print('Количество квартир без указания этажа:', data['floors_total'].isna().sum())
# Out:
# Количество квартир без указания этажа: 86

# %% [markdown]
# Отсутствующих значений всего 86 из 23699 строк - это всего 0.36%, предлагаю удалить данные и изменить их тип:

# %%
data.dropna(subset=['floors_total'], inplace = True, axis = 0)
data['floors_total'] = data['floors_total'].astype('int')

# %% [markdown]
# Обработаем столбец living_area. Есть пустые данные, но зная общую площадь и количество комнат по каждой квартире можно вычислить, какой процент занимает жилая площадь для каждой квартиры (однокомнатной, двухкомнатной и тд.). Для начала изучим основное количество комнат в квартирах:

# %%
data['rooms'].value_counts()
# Out:
# 1     8015
# 2     7913
# 3     5795
# 4     1177
# 5      325
# 0      194
# 6      104
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# Основная часть квартир - это квартиры с 1,2,3,4,5 и 6 комнатами. Рассчитаем по медианным данным, какую часть квартиры занимает жилая площадь и заполним на основании этих данных пустые значения для 1,2,3,4,5 и 6 - комнатных квартир.

# %%
living_area_1_median = ((data.loc[(data['rooms'] == 1) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 1) & (data['living_area'].isnull() == False), 'total_area']).median())
living_area_2_median = ((data.loc[(data['rooms'] == 2) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 2) & (data['living_area'].isnull() == False), 'total_area']).median())
living_area_3_median = ((data.loc[(data['rooms'] == 3) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 3) & (data['living_area'].isnull() == False), 'total_area']).median())
living_area_4_median = ((data.loc[(data['rooms'] == 4) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 4) & (data['living_area'].isnull() == False), 'total_area']).median())
living_area_5_median = ((data.loc[(data['rooms'] == 5) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 5) & (data['living_area'].isnull() == False), 'total_area']).median())
living_area_6_median = ((data.loc[(data['rooms'] == 6) & (data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 6) & (data['living_area'].isnull() == False), 'total_area']).median())
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 1), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 1), 'total_area'] * living_area_1_median
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 2), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 2), 'total_area'] * living_area_2_median
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 3), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 3), 'total_area'] * living_area_3_median
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 4), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 4), 'total_area'] * living_area_4_median
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 5), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 5), 'total_area'] * living_area_5_median
data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 6), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & (data['rooms'] == 6), 'total_area'] * living_area_6_median

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Хочу задать вопрос. Как можно весь этот ужас записать лаконичнее и эффективнее? Я мозг сломал, пока правильно все это выводил, думал формулу применить, но у меня все полетело, я испугался и оставил как есть =D Но мне кажется есть варианты проше, как рассчитать отношение жилой к общей.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# 1. Да, можно через функции. Ниже показал.
#
# 2. Хочу немного придраться к оформлению, не принимай близко к сердцу)
#
#     Ты наверняка знаешь про формат [pep8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html#section-5), программисты стараются его придерживаться, чтобы облегчить друг другу жизнь. В блоке кода выше у тебя очень длинная строка, которую не очень удобно читать. На эту тему сообщество договорилось, что код должен быть не более 79 символов в строке, чтобы он помещался на обычном мониторе и не приходилось листать вправо. Считать символы не нужно, и pep8 соблюдать мы не требуем, но было бы здороро, если ты будешь помещать код в ширину ячейки jupyter notebook.
#
#     Ниже приведу примеры.
#
# </div>

# %%
# Код ревьюера

# Так можно преобразовать твой код
def cnt_median(num):
    return ((
            data.loc[
                (data['rooms'] == 1) & (data['living_area'].isnull() == False),
                'living_area'
            ] / data.loc[
                (data['rooms'] == 1) & (data['living_area'].isnull() == False),
                'total_area'
            ]
        ).median())

living_area_1_median = cnt_median(1)

# Аналогично можно преобразовать заполнение пропусков.

# Большие вычисления всегда можно взять в скобки
a = (1
    + 2
    + (3 - 4)
    - 5
    - 6)

print(a)
# Out:
# -9

# %% [markdown]
# Подсчитаем количество оставшихся пустых ячеек:

# %%
print(data['living_area'].isna().sum())
# Out:
# 18

# %% [markdown]
# Удалим их, так как на общую статистику они не повлияют.

# %%
data.dropna(subset=['living_area'], inplace = True, axis = 0)

# %% [markdown]
# Еще раз выведем количество комнат, так как было видно много значений с нулевым количеством комнат.

# %%
data['rooms'].value_counts()
# Out:
# 1     8015
# 2     7913
# 3     5795
# 4     1177
# 5      325
# 0      183
# 6      104
# 7       53
# 8       12
# 9        7
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# Квартир с комнатами свыше 9 мало, но они могут оказаться сильное влияние на средние значения. Посмотрим их:

# %%
data.query('rooms >= 10')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 648               3      17.500       183.7           2018-07-01     11
# 866               5      25.000       363.0           2017-12-23     14
# 4149              6      23.000       272.6           2018-01-11     10
# 5358             20      65.000       590.0           2019-02-14     15
# 9688              8      33.000       194.1           2017-02-07     11
# 14498             6      32.250       374.6           2018-06-09     19
# 18119             4      15.500       216.1           2016-07-04     10
# 18848             6      28.500       270.0           2015-03-02     16
# 18891            11      40.000       290.0           2016-06-21     10
# 19540             8     420.000       900.0           2017-12-06     12
# 20829             6      28.659       245.4           2016-03-31     14
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Несмотря на кажущиеся огромными значения, квартиры похожи на настоящие - соотношение цен, общей и жилой площади выдает в объявлениях вполне существующие варианты. Продолжим без удаления, видим 183 квартиры без комнат, вероятно - это студия. Проверим эту информацию.

# %%
data[data['rooms']==0]['studio'].value_counts()
# Out:
# True     128
# False     55
# Name: studio, dtype: int64

# %% [raw]
# Видим, что количество квартир, в которых 0 комнат, не совпадает с количеством студий. Посмотрим эти значения:

# %%
data.query('rooms == 0 and studio == False')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 349               4       2.320       25.00           2017-09-27      0
# 508               0       3.375       34.40           2017-03-28      0
# 839              14       1.900       35.00           2017-04-14      0
# 946               5       2.200       23.00           2016-09-27      0
# 1574              0       2.200       22.00           2017-11-03      0
# 1625              7       1.980       23.98           2018-02-01      0
# 2532              5       3.500       27.10           2018-02-01      0
# 3019             18       2.100       24.00           2017-11-10      0
# 4115              7       2.600       24.00           2018-02-01      0
# 4437             10       3.200       25.00           2017-10-16      0
# 4683              2       3.650       35.00           2018-02-01      0
# 4876              7       3.000       25.00           2017-09-27      0
# ...

# %% [markdown]
# Видим, что во всех этих квартирах не указана информация о площади кухни, что позволяет предположить, что перед нами студия. Заменим значения:

# %%
data['studio'] = data['studio'].where(((data['kitchen_area'] == 0) & (data['studio'] == False)), True)
data[data['rooms']==0]['studio'].value_counts()
# Out:
# True    183
# Name: studio, dtype: int64

# %% [markdown]
# Обработаем столбец is_apartment. Отличие апартаментов от квартир лишь в системе налогообложения, к тому же незаполнение данных, скорее всего, указывает на то, что перед нами именно квартира. Заполним данные на "False" и изменим их тип.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False).astype('bool')

# %% [markdown]
# Обработаем столбец kitchen_area. По тому же принципу, что и living_area, можем понять соотношение площади кухни к общей площади квартиры с каждым количеством комнат:

# %%
kitchen_area_1_median = ((data.loc[(data['rooms'] == 1) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 1) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
kitchen_area_2_median = ((data.loc[(data['rooms'] == 2) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 2) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
kitchen_area_3_median = ((data.loc[(data['rooms'] == 3) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 3) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
kitchen_area_4_median = ((data.loc[(data['rooms'] == 4) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 4) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
kitchen_area_5_median = ((data.loc[(data['rooms'] == 5) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 5) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
kitchen_area_6_median = ((data.loc[(data['rooms'] == 6) & (data['kitchen_area'].isnull() == False), 'kitchen_area']/data.loc[(data['rooms'] == 6) & (data['kitchen_area'].isnull() == False), 'total_area']).median())
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 1), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 1), 'total_area'] * kitchen_area_1_median
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 2), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 2), 'total_area'] * kitchen_area_2_median
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 3), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 3), 'total_area'] * kitchen_area_3_median
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 4), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 4), 'total_area'] * kitchen_area_4_median
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 5), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 5), 'total_area'] * kitchen_area_5_median
data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 6), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & (data['rooms'] == 6), 'total_area'] * kitchen_area_6_median

# %% [markdown]
# Найдем оставшиеся пустые значения и, если их немало, заполним их усредненными медианными значениями для корректности данных:

# %%
print('Количество пустых значений kitchen_area:', data['kitchen_area'].isna().sum())
kitchen_area_ratio_median = (data['kitchen_area'] / data['total_area']).median()
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area'] * kitchen_area_ratio_median)
print('Количество пустых значений kitchen_area:', data['kitchen_area'].isna().sum())
# Out:
# Количество пустых значений kitchen_area: 188
# Количество пустых значений kitchen_area: 0

# %% [markdown]
# Обработаем столбец balcony. Пропущенные значения говорят об отсутствии балкона, соответственно заменим пустые значения на ноль:

# %%
data['balcony'] = data['balcony'].fillna(0).astype('int')

# %% [markdown]
# Обработаем столбец locality_name. Пропущенных данных очень мало, их можно удалить.

# %%
data.dropna(subset=['locality_name'], inplace = True, axis = 0)

# %% [markdown]
# Обработаем столбцы parks_around3000 и ponds_around3000, остутствие значений с наибольшей вероятностью говорит о том, что рядом нет указанных объектов.

# %%
data['parks_around3000'] = data['parks_around3000'].fillna('0')
data['ponds_around3000'] = data['ponds_around3000'].fillna('0')

# %% [markdown]
# Для анализа данных обработка столбцов airports_nearest, parks_nearest и ponds_nearest не требуется, а вот с данными по cityCenters_nearest придется поработать. Для начала, посчитаем пустые значения.

# %%
print('Количество пустых значений в столбце cityCenters_nearest:', data['cityCenters_nearest'].isna().sum())
# Out:
# Количество пустых значений в столбце cityCenters_nearest: 5496

# %% [markdown]
# Удаление повлечет за собой потерю большого пласта данных, попробуем заполнить значения, исходя из имеющихся данных. Для исследования нужны данные по квартирам в Санкт-Петербурге, найдем пустые значения и удалим их, если их количество незначительно:

# %%
st_peter_data = data[data['locality_name'] == 'Санкт-Петербург']
print('Количество пустых значений в столбце cityCenters_nearest по Санкт-Петербургу:', st_peter_data['cityCenters_nearest'].isna().sum())
idx = data[(data['locality_name'] == 'Санкт-Петербург') & (data['cityCenters_nearest'].isna())].index
data = data.drop(index=idx)
print('Количество пустых значений в столбце cityCenters_nearest:', data['cityCenters_nearest'].isna().sum())
# Out:
# Количество пустых значений в столбце cityCenters_nearest по Санкт-Петербургу: 59
# Количество пустых значений в столбце cityCenters_nearest: 5437

# %% [markdown]
# Рассмотрим столбец days_exposition.

# %%
print('Количество пустых значений в столбце days_exposition:', data['days_exposition'].isna().sum())
# Out:
# Количество пустых значений в столбце days_exposition: 3131

# %% [markdown]
# Неприятная ситуация. Данных много, удалять их не хочется, но и восстановить не из чего. Возможно, данные квартиры не проданы, поэтому данные и не заполнены. Попробуем заполнить данные медианными значениями.

# %%
display(data[data['days_exposition'].isna()])
#смотрим пустые значения в days_exposition.
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20      13.000      108.00           2019-03-07      3
# 7                 5       7.915       71.60           2019-04-18      2
# 44               13       5.350       40.00           2018-11-18      1
# 45               17       5.200       50.60           2018-12-02      2
# 46               17       6.600       52.10           2019-01-31      2
# ...             ...         ...         ...                  ...    ...
# 23684            20      21.400      145.00           2018-11-02      4
# 23685            15       2.490       31.00           2019-01-24      1
# 23694             9       9.700      133.81           2017-03-21      3
# 23696            18       2.500       56.70           2018-02-11      2
# 23698             4       1.350       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
# Код ревьюера

data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

data[data['days_exposition'].isna()]['first_day_exposition'].hist(xrot=45)
plt.show()

# %%
data['days_exposition']=data['days_exposition'].astype('float64')
data['days_exposition']=data['days_exposition'].fillna(data['days_exposition'].median())
data['days_exposition']=data['days_exposition'].astype('int64')

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Было бы здорово перед заменой на медиану исследовать количество пропусков в `days_exposition` в зависимости от `first_day_exposition` и сделать дополнительные выводы, может и не стоило делать такую замену...
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Я так уже делал, но не вижу связи, first_day_exposition и в 2017, и в 2018, и в 2019 году. Думал сначала, что есть какая-то связь с Новым Годом, но нет. Или ты просто про дополнительный анализ? Я вообще хотел данные удалить, но удалять более 10% данных мне кажется некорректным решением.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">v2 Комментарий ревьюера (желтый)</font></h5>
#
# Тут не совсем корректно, заполнять пропуски, если изучить количество пропусков по дням, то видно, что ближе к концу периода пропусков больше, соответственно это просто не снятые объявления.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Теперь понятно. Но в таком случае их можно удалить? Для оценки они не совсем корректны, так как факт того, что квартира, допустим, не продается больше года, свидетельствует, скорее всего, о цене выше рынка. Альтернатива - посчитать дни до снятия объявления по текущей дате (в Slack в пример кидали этот сайт (https://pynative.com/python-difference-between-two-dates/), с которого можно взять информацию, но не уверен, можно ли использовать то, что не проходили. И, опять же, корректно ли будет указывать, что объявление снято сегодня, когда оно, по факту, не снято? Остается удаление?
#
# </div>

# %% [markdown]
# На всякий случай проверим явные дубликаты:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Считаем следующие значения:
# <br>1) цену квадратного метра;
# <br>2) день недели, месяц и год публикации объявления;
# <br>3) этаж квартиры; варианты — первый, последний, другой;
# <br>4) соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# Посчитаем цену квадратного метра (не забываем, что мы его делили для отображения в млн.руб) и приведем, для удобства, тип данных к int:

# %%
data['price_meter'] = (data['last_price'] * 1000000 / data['total_area']).astype('int')

# %% [markdown]
# Посчитаем день недели, месяц и год публикации объявления, добавим значения в столбцы:

# %%
data['day_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Добавляем этаж квартиры; варианты — первый, последний, другой;

# %%
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
    
data['floor_category'] = data.apply(floor_category, axis = 1)

# %% [markdown]
# Считаем соотношение жилой и общей площади, а также отношение площади кухни к общей:

# %%
data['ratio_living_total'] = data['living_area'] / data['total_area']
data['ratio_kitchen_total'] = data['kitchen_area'] / data['total_area']

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %% [markdown]
# Добавлены результаты в таблицу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра. Начнем с площади:

# %%
data['total_area'].hist(bins = 30, range = (0,250))
plt.title('Площадь квартир')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
# Out:
# Text(0, 0.5, 'Количество квартир')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Здорово, что ты используешь range, так нагляднее.
#
# </div>

# %% [markdown]
# Вывод: больше продается квартир площадью 45-49 кв.м.

# %%
data['last_price'].hist(bins=30, range=(0,20))
plt.title('Стоимость квартир')
plt.xlabel('Стоимость')
plt.ylabel('Количество квартир')
# Out:
# Text(0, 0.5, 'Количество квартир')

# %% [markdown]
# Вывод: самая популярная стоимость квартир находится в диапазоне от 2,5 до 5 млн.

# %%
data['rooms'].hist(bins=30,range=(0,7))
plt.title('Комнаты')
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')
# Out:
# Text(0, 0.5, 'Количество квартир')

# %% [markdown]
# Вывод: в продаже больше всего одно- и двухкомнатных квартир, трехкомнатных меньше, но не сильно.

# %%
data['ceiling_height'].hist(bins=30,range=(2,5))
plt.title('Потолки')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
# Out:
# Text(0, 0.5, 'Количество квартир')

# %% [markdown]
# Вывод: наибольшее число квартир с потолками около 2,6 метра.
# <br>
# <br>Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану. Посчитаем, сколько обычно занимает продажа и когда можно считать, что продажи прошли очень быстро, а когда необычно долго.

# %%
data['days_exposition'].hist(bins=50,range=(0,365))
print('Среднее время продажи:', data['days_exposition'].mean())
print('Медианное время продажи:', data['days_exposition'].median())
# Out:
# Среднее время продажи: 169.38968835149865
# Медианное время продажи: 95.0

# %% [markdown]
# Чаще всего квартиры продаются в период до 100 дней, и чем дольше весит объявление, тем меньше продаж. Медианное время продажи - 95 дней, среднее - 169 дней. Быстрой продажей можно считать срок до 50 дней, долгой - свыше 150.
# <br>
# <br> Теперь займемся редкими и выбивающимися значениями:

# %%
data['days_exposition'].hist(bins=100, range=(40,150))
plt.show()
plt.boxplot(data['days_exposition'])
plt.show()
plt.boxplot(data['rooms'])
plt.show()

# %% [markdown]
# Видим, что на 45, 60 и 90 дни исчезло много объявлений. Похоже, что они были удалены автоматически после определенного количества дней (может, настройки сайта?). Также возможно, что риэлтор обязывался продать квартиру в течение указанного времени, после чего удалял объявление. Верхний «ус» диаграммы размаха заканчивается около 450 секунд — это 1,5 межквартильного размаха, добавленного к 3-му квартилю. Это ориентировочная граница нормального размаха. Всё, что лежит за ней, считается выбросом. Более высокие значения рисуются отдельными точками, но сливаются в единую жирную линию: таких выбросов очень много. К тому же меня на протяжении всего исследования смущали значения свыше 5 в количестве комнат. Допускаю, что такие значения есть, но в нормальных размах по комнатам они тоже не входят. Избавимся и от них.

# %%
print('Количество строк до удаления выбросов:', len(data))
data = data.query('days_exposition < 450')
data = data.query('rooms <= 7')
print('Количество строк после удаления выбросов:', len(data))
# Out:
# Количество строк до удаления выбросов: 23488
# Количество строк после удаления выбросов: 21364

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Были оценены потери, это очень важно сделать перед тем, как избавляться от данных.
#
# </div>

# %% [markdown]
# Какие факторы больше всего влияют на стоимость квартиры? Изучим, зависит ли цена от площади, числа комнат, удалённости от центра. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года. Для этого составим корреляционные данные:

# %%
сorr_data_price = data[['price_meter', 'total_area', 'rooms', 'cityCenters_nearest']]
pd.plotting.scatter_matrix(сorr_data_price, figsize=(15, 15))
None

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Вывод перед графиком немного мешает. Он выводится так как jupyter notebook выводит на экран информацию об объекте в последней строке, чтобы этого не было, можно в конец добавить None, эти непонятные строки выводиться не будут. Показал в примере ниже.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Roger that. Добавил None в свой код.
#
# </div>

# %%
сorr_data_price.corr()
# Out:
#                      price_meter  total_area     rooms  cityCenters_nearest
# price_meter             1.000000    0.288089  0.040772            -0.315883
# total_area              0.288089    1.000000  0.749333            -0.226913
# rooms                   0.040772    0.749333  1.000000            -0.174748
# cityCenters_nearest    -0.315883   -0.226913 -0.174748             1.000000

# %% [markdown]
# Построим коэффициент корреляции Пирсона между всеми парами столбцов. Видим, что корреляция в пределах нормы, цена слабо зависит от общей площади и числа комнат, но умеренно зависит от удалённости от центра.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Не посчитан и не интерпретирован коэффициент корреляции Пирсона.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Исправил.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Вывод: Цена не сильно зависит от площади квартиры и от количества комнат (хотя в трешках стоимость чуть выше, чем в однушках), но зависит от расстояния до центра.
# Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
(
    data.pivot_table(index='floor_category', values='last_price', aggfunc='median')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# Вывод: цена квартир на первом этаже значительно ниже, чем между первым и последним. Цена на последнем этаже выше, чем на первом, но тоже ниже, чем между первым и последним. Изучим зависимость от даты размещения: дня недели, месяца и года.

# %%
(
    data.pivot_table(index='day_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
(
    data.pivot_table(index='month_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.show()
(
    data.pivot_table(index='year_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# Вывод: дороже всего квартиры, опубликованные в субботу, дешевле всего в пятницу и воскресенье. В ноябре квартиры дешевле, чем в апреле и сентябре. Пик продаж традиционно приходится на начала осени и весны. Стоимость квартир падала до 2018 года, к 2019 году начала подниматься. Следующим шагом выберем 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим среди них населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
ten_best_cities = data.pivot_table(index='locality_name', values='price_meter', aggfunc=('count','mean'))
ten_best_cities = ten_best_cities.astype(int)
ten_best_cities_sort = ten_best_cities.sort_values(by='count', ascending=False).head(10).reset_index()
display(ten_best_cities_sort)
# Out:
#        locality_name  count    mean
# 0    Санкт-Петербург  14110  114139
# 1     посёлок Мурино    479   85902
# 2     посёлок Шушары    409   78560
# 3         Всеволожск    359   68792
# 4             Пушкин    336  102813
# 5            Колпино    316   75296
# 6  посёлок Парголово    306   90001
# 7            Гатчина    279   68908
# 8    деревня Кудрово    264   92673
# 9             Выборг    216   58186

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Построй, пожалуйста, столбчатую диаграмму или ящики с усами по топ 10 населенным пунктам.
#
#
# </div>

# %%
ten_best_cities_sort.plot(x='locality_name', kind='bar', grid=True) 
None

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">v2 Комментарий ревьюера (красный)</font></h5>
#
# 1. Не верно строится график, повтори, пожалуйста, спринт «Исследовательский анализ данных», урок «Изучение срезов данных», тему «Графики»(столбчатая диаграмма — это разновидность графиков, можно получить параметром `kind='bar`).
#
# 2. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Исправлено. Почему-то не сохранилась последняя версия при отправлении.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v3 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Вывод: дороже всего квадратный метр стоит в Санкт-Петербурге и Пушкине, дешевле всего в Выборге, Гатчине и Всеволжске.

# %% [markdown]
# Изучим предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделим квартиры в Санкт-Петербурге (locality_name). Наша задача — выяснить, какая область входит в центр. Создадим столбец с расстоянием до центра в километрах: округлим до целых значений. После этого посчитаем среднюю цену для каждого километра. Построим график: он должен показывать, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется, — это и будет центральная зона.

# %%
data['center_km'] = data['cityCenters_nearest'] / 1000
data['center_km'] = data['center_km'].fillna(value=0).astype(int)

(
    data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='center_km', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.show()

# %% [markdown]
# Вывод: центральная зона в пределах 7 км., после цена резко снижается.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Да, тут верно определен центр 🤗
#
# </div>

# %% [markdown]
# Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
spb_center_data = data.query('center_km <= 7 and locality_name == "Санкт-Петербург"')
spb_center_data['total_area'].hist(bins=50,range=(0,300))
plt.title('Площадь квартир в центре Санкт-Петербурга')
plt.xlabel('Площадь')
plt.ylabel('Количество квартир')
plt.show()
spb_center_data['last_price'].hist(bins=50,range=(0,60))
plt.title('Стоимость квартир в центре Санкт-Петербурга')
plt.xlabel('Стоимость')
plt.ylabel('Количество квартир')
plt.show()
spb_center_data['rooms'].hist(bins=50,range=(0,8))
plt.title('Количество комнат в центре Санкт-Петербурга')
plt.xlabel('Комнаты')
plt.ylabel('Количество квартир')
plt.show()
spb_center_data['ceiling_height'].hist(bins=50,range=(2,4))
plt.title('Высота потолков в центре Санкт-Петербурга')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# Выводы:
# <br>1) Основная площадь квартир в центре Санкт-Петербурга от 45 до 100 кв.м.
# <br>2) Стоимость большей части квартир в центре Санкт-Петербурга - от 5 до 10 млн.
# <br>3) В центре Санкт-Петербурга двух- и трехкомнатные квартиры преобладают над однокомнатными, есть и четырех- и пятикомнатные.
# <br>4) Высота потолков либо 2,5, либо 3 метра. Остальных значений не так много.
# <br>Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).

# %%
(
    spb_center_data.query('rooms > 0').pivot_table(index='rooms', values='price_meter')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
(
    spb_center_data.query('floor > 0').pivot_table(index='floor_category', values='price_meter')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
(
    spb_center_data.pivot_table(index='cityCenters_nearest', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5), alpha=0.06)
)
plt.show()
(
    spb_center_data.pivot_table(index='day_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
(
    spb_center_data.pivot_table(index='month_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
plt.show()
(
    spb_center_data.pivot_table(index='year_exposition', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# 1. Обрати внимание на то, что на данном графике все точки слились в большое пятно.
#
#     Повтори, пожалуйста, еще раз в спринт «Исследовательский анализ данных» тему «Взаимосвязь данных» урок «Корреляция» и попробуй добавить параметр прозрачности.
#
# 2. Нет сравнения коэффициентов корреляций Пирсона в СПб и по всей базе.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Добавил ниже корреляцию. Параметр прозрачности добавил в график выше.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Дополнительно посмотрим корреляцию Пирсона в СПБ и по всей базе:

# %%
print ('Корреляция в СПБ:')
print(spb_center_data[['last_price', 'rooms','floor','cityCenters_nearest']].corr())
print()
print ('Корреляция общая:')
print(data[['last_price', 'rooms','floor','cityCenters_nearest']].corr())
# Out:
# Корреляция в СПБ:
#                      last_price     rooms     floor  cityCenters_nearest
# last_price             1.000000  0.313637  0.100221            -0.066536
# rooms                  0.313637  1.000000 -0.046465            -0.186289
# floor                  0.100221 -0.046465  1.000000             0.258314
# cityCenters_nearest   -0.066536 -0.186289  0.258314             1.000000
#
# Корреляция общая:
#                      last_price     rooms     floor  cityCenters_nearest
# last_price             1.000000  0.338286  0.027175            -0.202471
# rooms                  0.338286  1.000000 -0.154120            -0.174748
# floor                  0.027175 -0.154120  1.000000             0.004414
# cityCenters_nearest   -0.202471 -0.174748  0.004414             1.000000

# %% [markdown]
# Коэффициенты корреляции зависимости цены от количества комнат практически совпадают, имеется небольшая разница между коэффициентами корреляции зависимости цены от этажа и от близости к центру. Вполне естественно, что в центре СПБ нет большой разницы, где именно в центре находится квартира, поэтому и коэффициент меньше. Зависимость цены от этажа в центре СПБ прослеживается чуть выше, чем по основным данным, но все еще невелика. Сравним коэффиценты корреляции по дате размещения объявления:

# %%
print ('Корреляция по времени подачи объявления в СПБ:')
print(spb_center_data[['last_price', 'day_exposition','month_exposition','year_exposition']].corr())
print()
print ('Корреляция по времени подачи объявления общая:')
print(data[['last_price', 'day_exposition','month_exposition','year_exposition']].corr())
# Out:
# Корреляция по времени подачи объявления в СПБ:
#                   last_price  day_exposition  month_exposition  \
# last_price          1.000000        0.017175         -0.019324
# day_exposition      0.017175        1.000000          0.023935
# month_exposition   -0.019324        0.023935          1.000000
# year_exposition    -0.032831       -0.008911         -0.284873
#
#                   year_exposition
# last_price              -0.032831
# day_exposition          -0.008911
# month_exposition        -0.284873
# year_exposition          1.000000
#
# Корреляция по времени подачи объявления общая:
#                   last_price  day_exposition  month_exposition  \
# last_price          1.000000        0.000696         -0.003635
# day_exposition      0.000696        1.000000          0.013927
# month_exposition   -0.003635        0.013927          1.000000
# year_exposition    -0.021945       -0.013854         -0.309592
#
#                   year_exposition
# ...

# %% [markdown]
# Коэффициенты корреляции зависимости цены от времени подачи объявления практические не отличаются - в действительности зависимость стоимости квартир одинаково распределена от времени публикации и в центре СПБ, и в остальной таблице.

# %% [markdown]
# Выводы:
# <br>1) Стоимость за квадратный метр повышается к количеству комнат, но на графике видно, что  цена за кв.м. в однокомнатных квартирах достигает 152 тыс., в то время, как двух- и трехкомнатную стоимость около 142 тыс.
# <br>2) Стоимость зависит от этажа - она ниже на первом этаже, но на последнем стоит почти также, как и на остальных. Стоимость квартир не на первом и не на последнем этажах колеблется в диапозоне от 120 до 155 тыс. руб. за кв.м.
# <br>3) В самом центре Санкт-Петербурга цена не сильно отличается, в пределах 8 км. ~~все дорого~~ все одинаково.
# <br>4) Дороже всего квартиры, опубликованные в субботу, дешевле всего в среду, четверг и пятницу. В апреле и сентябре квартиры дороже, чем в августе и ноябре. Стоимость квартир падала до 2018 года, к 2019 году начала подниматься.
# <br>Отличаются ли они от общих выводов по всей базе? В целом данные не отличаются от общей базы, но есть интересная особенность: в центре Санкт-Петербурга есть очень дорогие однокомнатные квартиры и последний этаж стоит не сильно дешевле остальных.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ##### Анализ информации
#
# В ходе проведения анализа информации о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет проведена предобработка данных:
# - Изменили тип данных об общей стоимости на целочисленный и приведен к миллионам;
# - Дата публикации приведена к формату %Y-%m-%dT%H:%M:%S;
# - Устранены аномалии и некорректные значения в столбце о высоте потолков к реальным значениям;
# - Удалены данные о квартирах без указания этажа, города;
# - Рассчитаны жилая и кухонная площади в зависимости от общего количества комнат квартиры и соотношения этих площадей к общей площади квартиры, оставшиеся данные удалены (18 квартир);
# - Заполнены данные о студиях на основании отсутствующих данных о площадях кухни, заполнены данные об апартаментах и наличии рядом прудов и парков на основании отсутствующих значений (пусто – значит нет);
# - Удалили 59 квартир из г.Санкт-Петербург, по которым не указано расстояние до центра города, так как эти данные будут мешать анализу, а восстановить данные не представляется возможным;
# - Зависимость продолжительности срока публикации от остальных данных найдена не была, в связи с чем заполнили отсутствующие данные медианным значением.
# - Проверили явные дубликаты и удалили их.
#
# ##### Добавление данных
#
# В целях использования в дальнейшем анализе в таблицу добавлены следующие данные:
# - цена квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# ##### Изучение параметров
#
# Изучили и отобразили графически следующие параметры: площадь, цена, число комнат, высота потолков. Выявили следующие факты:
# - больше продается квартир площадью 45-49 кв.м.;
# - самая популярная стоимость квартир находится в диапазоне от 2,5 до 5 млн.;
# - в продаже больше всего одно- и двухкомнатных квартир;
# - наибольшее число квартир с потолками около 2,6 метра.
#
# ##### Удаление выбросов
#
# Удалены выбросы, найденные по диаграмме размаха (срок размещения объявления и количество квартир). Количество строк после удаления выбросов уменьшилось до 21364, но их качество значительно возросло.
#
# ##### Оценка общих данных
#
# Оценено время продажи квартир. Чаще всего квартиры продаются в период до 100 дней, и чем дольше весит объявление, тем меньше продаж. Медианное время продажи - 95 дней, среднее - 169 дней. Быстрой продажей можно считать срок до 50 дней, долгой - свыше 150.
# Оценено, какие факторы больше всего влияют на стоимость квартиры. Цена не сильно зависит от площади квартиры и от количества комнат (хотя в трешках стоимость чуть выше, чем в однушках), но зависит от расстояния до центра. Цена квартир на первом этаже значительно ниже, чем между первым и последним. Цена на последнем этаже выше, чем на первом, но тоже ниже, чем между первым и последним.  Дороже всего оказались квартиры, опубликованные в субботу, дешевле всего в пятницу и воскресенье. В ноябре квартиры дешевле, чем в апреле и сентябре. Стоимость квартир падала до 2018 года, к 2019 году начала подниматься.
#
# ##### ТОП-10 населенных пунктов
#
# Выбрали 10 населённых пунктов с наибольшим числом объявлений. Дороже всего квадратный метр стоит в Санкт-Петербурге (около 114 000 руб. за кв.м.) и Пушкине, дешевле всего в Выборге (58 000 тыс. руб. за кв.м.), Гатчине и Всеволжске.
#
# ##### Оценка данных центра СПБ и сравнение с общими данными
#
# Выделен центр Санкт-Петербурга диаметром в 7 километров.
# Выделен сегмент квартир в центре и проанализирован, сделаны следующие выводы:
# - Основная площадь квартир в центре Санкт-Петербурга от 45 до 100 кв.м.
# - Стоимость большей части квартир в центре Санкт-Петербурга - от 5 до 10 млн.
# - В центре Санкт-Петербурга двух- и трехкомнатные квартиры преобладают над однокомнатными, есть и четырех- и пятикомнатные.
# - Высота потолков либо 2,5, либо 3 метра.
# - Стоимость за квадратный метр повышается к количеству комнат, но на графике видно, что цена за кв.м. в однокомнатных квартирах достигает 152 тыс., в то время, как двух- и трехкомнатную стоимость около 142 тыс.
# - Стоимость зависит от этажа - она ниже на первом этаже, но на последнем стоит почти также, как и на остальных. Стоимость квартир не на первом и не на последнем этажах колеблется в диапозоне от 120 до 155 тыс. руб. за кв.м.
# - Дороже всего квартиры, опубликованные в субботу, дешевле всего в среду, четверг и пятницу. В апреле и сентябре квартиры дороже, чем в августе и ноябре. Стоимость квартир падала до 2018 года, к 2019 году начала подниматься.
# Отличий квартир в центре Санкт-Петербурга от остальной базы не так много, но выявлено, что в центре Санкт-Петербурга есть очень дорогие однокомнатные квартиры и последний этаж стоит не сильно дешевле остальных. Разумеется, в среднем цена за кв.м. выше, чем в других городах, как и средняя стоимость продающейся квартиры.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# У меня хрустит до сих пор) Не переживай, это нормальное состояние)
#
# В общем выводе хочется тезисно видеть все промежуточные выводы с цифрами. Это очень важно, поскольку топ-менеджеры, в большинстве своем, смотрят сразу сюда и только сюда...
#
# Тут важно обратиться к целям, которые были озвучены в самом начале и ответить на все вопросы. Важно оформить все тезисно и с цифрами. Еще важно описать все промежуточные выводы, которых не прописано в целях.
# Вкратце структура такая:
# - как были предобработаны данные(тут важно написать про изменения, если заполнялись пропуски или преобразовывались строки)
# - пройдись по целям и ответь на вопросы
# - добавь промежуточные выводы, которые считаешь нужным отметить
#
# Еще очень важно помнить, для кого ты делаешь проект, в зависимости от этого нужно сделать определенные акценты. В данном случае проект учебный, поэтому нужно ориентироваться по описанию.
#
# Оформи, пожалуйста, красиво с помощью [Краткого руководства по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">v2 Комментарий ревьюера (красный)</font></h5>
#
# Не исправлено.
#
# Вывод — один большой абзац текста, будет более читаемо, если ты оформишь тезисами, можешь воспользоваться [Кратким руководством по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Но... было... исправлено! Почему-то не сохранилась последняя версия работы. Теперь исправил.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v3 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# Бывают сбои, рекомендую сохранять работу локально перед отправкой.
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что ты ведешь чек-лист, он помогает ничего не забыть!
#
# </div>
